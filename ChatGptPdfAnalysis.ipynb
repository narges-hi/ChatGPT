# %%
# !pip install PyPDF2
# !pip install spacy

import PyPDF2
import spacy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !python -m spacy download en_core_web_sm
# Out:
# 2023-05-25 07:55:15.366547: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 20.1 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pdf_file_path = '/content/drive/MyDrive/Colab Notebooks/CLRS.pdf'
with open(pdf_file_path, 'rb') as file:
    pdf_reader = PyPDF2.PdfReader(file)
    text = ''
    for page in pdf_reader.pages:
        text += page.extract_text()

# %%
# Increase the maximum length limit
nlp = spacy.load('en_core_web_sm')
nlp.max_length = 3000000  # Set the limit to a suitable value based on your text length

# Process the text
doc = nlp(text)

# %%
# Counting the number of sentences
sentences = list(doc.sents)
num_sentences = len(sentences)
print("Number of sentences:", num_sentences)

# Extracting named entities
entities = list(doc.ents)
#for entity in entities:
 #   print(entity.text, entity.label_)
# Out:
# Number of sentences: 19354

# %%
# Conversation loop
while True:
    # Get user input
    question = input("Ask a question about the PDF (or enter 'exit' to quit): ")
    
    # Check if user wants to exit
    if question.lower() == 'exit':
        break
    
    # Process the user question using spaCy
    question_doc = nlp(question)
    
    # Perform analysis or answer the question based on its content
    # Example: Counting the number of sentences
    if 'number of sentences' in question.lower():
        sentences = list(doc.sents)
        num_sentences = len(sentences)
        print("Number of sentences:", num_sentences)
    else:
        # Provide a default response if the question is not recognized
        print("I'm sorry, I don't have the information to answer that question.")
# Out:
# Ask a question about the PDF (or enter 'exit' to quit): what is heap
# I'm sorry, I don't have the information to answer that question.
# Ask a question about the PDF (or enter 'exit' to quit): what is the main topic of the document
# I'm sorry, I don't have the information to answer that question.
# Ask a question about the PDF (or enter 'exit' to quit): how many sentence does the documnet have
# I'm sorry, I don't have the information to answer that question.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-4d5b6744cb2c> in <cell line: 2>()
#       2 while True:
#       3     # Get user input
# ----> 4     question = input("Ask a question about the PDF (or enter 'exit' to quit): ")
#       5
#       6     # Check if user wants to exit
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
# ...

# %%
# Conversation loop
while True:
    # Get user input
    question = input("Ask a question about the PDF (or enter 'exit' to quit): ")
    
    # Check if user wants to exit
    if question.lower() == 'exit':
        break
    
    # Process the user question using spaCy
    question_doc = nlp(question)
    
    # Perform analysis or answer the question based on its content
    # Example: Counting the number of sentences
    sentences = list(doc.sents)
    num_sentences = len(sentences)
    
    # Provide a response based on the question
    if 'number of sentences' in question.lower():
        print("Number of sentences:", num_sentences)
    elif 'keywords' in question.lower():
        # Extract and display keywords from the document
        keywords = [token.text for token in doc if not token.is_stop and token.is_alpha and token.pos_ != 'PUNCT']
        print("Keywords:", ', '.join(keywords))
    else:
        print("I'm sorry, I don't have the information to answer that question.")
